# %% [markdown]
# # Spencer Porter's Capstone

# %% [markdown]
# Goals
#
# Idea #1
#
# My general Capstone idea is around cyclists and the number of accidents in x cities. I haven't decided if I want to limit my research to just SF or expand it to include NYC, LA, CHI, and perhaps a foreign city, depending on if I can get my hands on the data set.
#
# I will use this cycling data to find a relationship between the number of cyclists on the road and the number of cycling accidents. I'd like to see if there is a correlation between the rates of cycling accidents and the types of riders in each city, i.e if there are more 'serious' riders than 'casual' commuters in SF, will that translate to mean there are fewer accidents per capita since the serious 'riders' are presumably more comfortable on the road and with traffic laws, etc.?
#
# I want to also gather weather data to find a correlation between non-ideal weather conditions/time of year and peaks in cycling accidents.
#
# Ultimately I'd like to arrive to a conclusion about what city is the most unsafe for cyclers as well as what time of year will produce the highest likelihood of being involved in an accident.

# %% [markdown]
# Idea #2
#
# I'd leverage the cyclist count data from the first idea but then also incorporate bike theft data from different cities. I found a dataset that has crime data by neighborhood, so I'd use that information to predict the likelihood of getting your bike stolen for different cities, and different neighborhoods.

# %% [markdown]
# Idea #3
#
# Music
#
# -types of music over 10 year timeframe for x number of major music festivals
#
# -which genres were the most popular vs. which are becoming the most popular?
#
# -the demographics of the festivals and how that could have an impact on the type of music being played at the festivals

# %% [markdown]
# Links to datasets:
#
# SF crime data: https://data.sfgov.org/Public-Safety/SFPD-Incidents-from-1-January-2003/tmnf-yvry
#
# NY crime data: https://data.cityofnewyork.us/Public-Safety/NYPD-Motor-Vehicle-Collisions/h9gi-nx95/data

# %%
#NYC crime dataset that includes columns about cyclist accidents

import pandas as pd
import numpy as np

bikes = pd.read_csv("../../../Desktop/datasets/NYPD_Motor_Vehicle_Collisions.csv")
crime = pd.read_csv("../../../Desktop/datasets/SFPD_Incidents_-_from_1_January_2003.csv")

# %%
bikes.head()
# Out:
#          DATE   TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/10/2016  15:11       NaN       NaN        NaN        NaN
# 1  04/16/2016   4:13       NaN       NaN  40.767373 -73.950057
# 2  04/16/2016   4:22       NaN       NaN        NaN        NaN
# 3  04/16/2016   4:30     BRONX   10468.0  40.862679 -73.909040
# 4  04/16/2016   4:30  BROOKLYN   11249.0  40.716508 -73.961275
#
#                     LOCATION   ON STREET NAME  CROSS STREET NAME  \
# 0                        NaN    MONROE STREET                NaN
# 1   (40.767373, -73.9500574)   EAST 68 STREET                NaN
# 2                        NaN    BORDEN AVENUE        58TH STREET
# 3  (40.8626793, -73.9090397)  SEDGWICK AVENUE  WEST FORDHAM ROAD
# 4  (40.7165078, -73.9612751)              NaN                NaN
#
#     OFF STREET NAME         ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 0               NaN         ...                            Unspecified
# ...

# %%
crime.head()
# Out:
#    IncidntNum        Category                                  Descript  \
# 0   150013666   DRUG/NARCOTIC           POSSESSION OF BASE/ROCK COCAINE
# 1   150013666   DRUG/NARCOTIC  POSSESSION OF BASE/ROCK COCAINE FOR SALE
# 2   150026528     WEAPON LAWS                     POSSESSION OF AIR GUN
# 3   150026534  SUSPICIOUS OCC                     SUSPICIOUS OCCURRENCE
# 4   150377989  SUSPICIOUS OCC                   INVESTIGATIVE DETENTION
#
#   DayOfWeek        Date   Time PdDistrict      Resolution  \
# 0    Monday  01/05/2015  15:55   NORTHERN  ARREST, BOOKED
# 1    Monday  01/05/2015  15:55   NORTHERN  ARREST, BOOKED
# 2    Friday  01/09/2015  14:36    MISSION  ARREST, BOOKED
# 3  Thursday  01/08/2015  11:30   RICHMOND       UNFOUNDED
# 4    Friday  05/01/2015  04:32    CENTRAL            NONE
#
#                     Address           X          Y  \
# 0  800 Block of OFARRELL ST -122.418751  37.785116
# 1  800 Block of OFARRELL ST -122.418751  37.785116
# ...
